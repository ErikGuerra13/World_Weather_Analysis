# %%
#import the dependecies
import random
import pandas as pd
import numpy as np
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import requests
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create a empty list to hold the weather data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for loggin purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run a API request for each of the cities 
    try:
        #Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vallenar
# Processing Record 2 of Set 1 | luwuk
# Processing Record 3 of Set 1 | mana
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | sapa
# Processing Record 6 of Set 1 | olafsvik
# Processing Record 7 of Set 1 | san juan
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | faya
# Processing Record 12 of Set 1 | nevinnomyssk
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | lac du bonnet
# Processing Record 17 of Set 1 | pankrushikha
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | antsohihy
# Processing Record 23 of Set 1 | charters towers
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | decatur
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | whitley bay
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | bathsheba
# Processing Record 32 of Set 1 | bay roberts
# Processing Record 33 of Set 1 | malakal
# Processing Record 34 of Set 1 | biak
# Processing Record 35 of Set 1 | san patricio
# Processing Record 36 of Set 1 | college
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | sur
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | katsuura
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | nchelenge
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | rawson
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | blagoyevo
# Processing Record 5 of Set 2 | cockburn town
# Processing Record 6 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | plettenberg bay
# Processing Record 9 of Set 2 | vila
# Processing Record 10 of Set 2 | comodoro rivadavia
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | chicama
# Processing Record 14 of Set 2 | ostrovnoy
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | kedougou
# Processing Record 17 of Set 2 | ornskoldsvik
# Processing Record 18 of Set 2 | henties bay
# Processing Record 19 of Set 2 | pathein
# Processing Record 20 of Set 2 | saint george
# Processing Record 21 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | palm beach
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | cayenne
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | paris
# Processing Record 28 of Set 2 | burica
# City not found. Skipping...
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | hamilton
# Processing Record 32 of Set 2 | wanaka
# Processing Record 33 of Set 2 | morro bay
# Processing Record 34 of Set 2 | shiyan
# Processing Record 35 of Set 2 | tyukhtet
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | hvolsvollur
# Processing Record 40 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | inirida
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | sakaiminato
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | chiredzi
# Processing Record 50 of Set 2 | ushuaia
# Processing Record 1 of Set 3 | kruisfontein
# Processing Record 2 of Set 3 | cidreira
# Processing Record 3 of Set 3 | ascope
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 6 of Set 3 | lubao
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 3 | palauig
# Processing Record 10 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 3 | nemuro
# Processing Record 12 of Set 3 | vozhega
# Processing Record 13 of Set 3 | praia
# Processing Record 14 of Set 3 | saint-max
# Processing Record 15 of Set 3 | saskylakh
# Processing Record 16 of Set 3 | lagoa
# Processing Record 17 of Set 3 | hanmer springs
# Processing Record 18 of Set 3 | maunabo
# Processing Record 19 of Set 3 | viedma
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | murray bridge
# Processing Record 22 of Set 3 | maryborough
# Processing Record 23 of Set 3 | ballina
# Processing Record 24 of Set 3 | roma
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | evensk
# Processing Record 27 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 3 | mapiri
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | jahrom
# City not found. Skipping...
# Processing Record 31 of Set 3 | mirnyy
# Processing Record 32 of Set 3 | mackay
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | cabedelo
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | guaymas
# Processing Record 38 of Set 3 | prince george
# Processing Record 39 of Set 3 | lyubech
# Processing Record 40 of Set 3 | rocha
# Processing Record 41 of Set 3 | jian
# Processing Record 42 of Set 3 | karanganom
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | meulaboh
# Processing Record 46 of Set 3 | cape town
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 49 of Set 3 | senanga
# Processing Record 50 of Set 3 | leningradskiy
# Processing Record 1 of Set 4 | shellbrook
# Processing Record 2 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 4 | road town
# Processing Record 5 of Set 4 | san rafael
# Processing Record 6 of Set 4 | busselton
# Processing Record 7 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | mathathane
# Processing Record 10 of Set 4 | cap malheureux
# Processing Record 11 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 12 of Set 4 | riyadh
# Processing Record 13 of Set 4 | mayumba
# Processing Record 14 of Set 4 | shyryayeve
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | ust-tarka
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | trofors
# Processing Record 19 of Set 4 | raga
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | caravelas
# Processing Record 22 of Set 4 | murdochville
# Processing Record 23 of Set 4 | aklavik
# Processing Record 24 of Set 4 | nan
# Processing Record 25 of Set 4 | biltine
# Processing Record 26 of Set 4 | dubna
# Processing Record 27 of Set 4 | oistins
# Processing Record 28 of Set 4 | lorengau
# Processing Record 29 of Set 4 | mount gambier
# Processing Record 30 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 4 | nago
# Processing Record 32 of Set 4 | ambilobe
# Processing Record 33 of Set 4 | havoysund
# Processing Record 34 of Set 4 | baruun-urt
# Processing Record 35 of Set 4 | tadine
# Processing Record 36 of Set 4 | aksarka
# Processing Record 37 of Set 4 | barentu
# Processing Record 38 of Set 4 | ola
# Processing Record 39 of Set 4 | yar-sale
# Processing Record 40 of Set 4 | deputatskiy
# Processing Record 41 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | umm lajj
# Processing Record 44 of Set 4 | terenga
# City not found. Skipping...
# Processing Record 45 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 4 | talnakh
# Processing Record 47 of Set 4 | tacuarembo
# Processing Record 48 of Set 4 | itoman
# Processing Record 49 of Set 4 | saint-leu
# Processing Record 50 of Set 4 | calabozo
# Processing Record 1 of Set 5 | spencer
# Processing Record 2 of Set 5 | kamenka
# Processing Record 3 of Set 5 | salinas
# Processing Record 4 of Set 5 | slatina
# Processing Record 5 of Set 5 | uige
# Processing Record 6 of Set 5 | atbasar
# Processing Record 7 of Set 5 | matara
# Processing Record 8 of Set 5 | bonaventure
# Processing Record 9 of Set 5 | jardim
# Processing Record 10 of Set 5 | noumea
# Processing Record 11 of Set 5 | chengdu
# Processing Record 12 of Set 5 | yankton
# Processing Record 13 of Set 5 | nioki
# Processing Record 14 of Set 5 | victoria
# Processing Record 15 of Set 5 | ponta do sol
# Processing Record 16 of Set 5 | wagrowiec
# Processing Record 17 of Set 5 | shimanovsk
# Processing Record 18 of Set 5 | poronaysk
# Processing Record 19 of Set 5 | lengshuitan
# Processing Record 20 of Set 5 | lieksa
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | port said
# Processing Record 23 of Set 5 | pemba
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | buin
# Processing Record 26 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 27 of Set 5 | chato
# Processing Record 28 of Set 5 | tres arroyos
# Processing Record 29 of Set 5 | jati
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | churapcha
# Processing Record 32 of Set 5 | bereda
# Processing Record 33 of Set 5 | acapulco
# Processing Record 34 of Set 5 | ayagoz
# Processing Record 35 of Set 5 | laramie
# Processing Record 36 of Set 5 | santa cruz del sur
# Processing Record 37 of Set 5 | kaoma
# Processing Record 38 of Set 5 | matamoros
# Processing Record 39 of Set 5 | jiayuguan
# Processing Record 40 of Set 5 | rafaela
# Processing Record 41 of Set 5 | karpogory
# Processing Record 42 of Set 5 | sherwood
# Processing Record 43 of Set 5 | san jeronimo
# Processing Record 44 of Set 5 | casas grandes
# Processing Record 45 of Set 5 | nouadhibou
# Processing Record 46 of Set 5 | nkan
# Processing Record 47 of Set 5 | norsup
# Processing Record 48 of Set 5 | okhotsk
# Processing Record 49 of Set 5 | santa rosalia
# Processing Record 50 of Set 5 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 1 of Set 6 | broken hill
# Processing Record 2 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | coquimbo
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | muroto
# Processing Record 7 of Set 6 | ugleuralskiy
# Processing Record 8 of Set 6 | santa vitoria do palmar
# Processing Record 9 of Set 6 | khandyga
# Processing Record 10 of Set 6 | abu samrah
# Processing Record 11 of Set 6 | bara
# Processing Record 12 of Set 6 | eyl
# Processing Record 13 of Set 6 | kaeo
# Processing Record 14 of Set 6 | beyneu
# Processing Record 15 of Set 6 | kysyl-syr
# Processing Record 16 of Set 6 | sompeta
# Processing Record 17 of Set 6 | airai
# Processing Record 18 of Set 6 | rundu
# Processing Record 19 of Set 6 | taboga
# Processing Record 20 of Set 6 | ahipara
# Processing Record 21 of Set 6 | ancud
# Processing Record 22 of Set 6 | luderitz
# Processing Record 23 of Set 6 | shingu
# Processing Record 24 of Set 6 | bilibino
# Processing Record 25 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 6 | nantucket
# Processing Record 27 of Set 6 | touros
# Processing Record 28 of Set 6 | vardo
# Processing Record 29 of Set 6 | hami
# Processing Record 30 of Set 6 | fredericksburg
# Processing Record 31 of Set 6 | portland
# Processing Record 32 of Set 6 | havre-saint-pierre
# Processing Record 33 of Set 6 | gazanjyk
# Processing Record 34 of Set 6 | sinnamary
# Processing Record 35 of Set 6 | eenhana
# Processing Record 36 of Set 6 | ossora
# Processing Record 37 of Set 6 | salalah
# Processing Record 38 of Set 6 | cherskiy
# Processing Record 39 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 6 | provideniya
# Processing Record 41 of Set 6 | los llanos de aridane
# Processing Record 42 of Set 6 | kermanshah
# Processing Record 43 of Set 6 | ca mau
# Processing Record 44 of Set 6 | pacific grove
# Processing Record 45 of Set 6 | alta floresta
# Processing Record 46 of Set 6 | kismayo
# Processing Record 47 of Set 6 | esperance
# Processing Record 48 of Set 6 | vila franca do campo
# Processing Record 49 of Set 6 | brockville
# Processing Record 50 of Set 6 | thompson
# Processing Record 1 of Set 7 | middelburg
# Processing Record 2 of Set 7 | port keats
# Processing Record 3 of Set 7 | montauban
# Processing Record 4 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 7 | laguna
# Processing Record 6 of Set 7 | bafq
# Processing Record 7 of Set 7 | longyearbyen
# Processing Record 8 of Set 7 | colares
# Processing Record 9 of Set 7 | port blair
# Processing Record 10 of Set 7 | bagdarin
# Processing Record 11 of Set 7 | lincoln
# Processing Record 12 of Set 7 | klaksvik
# Processing Record 13 of Set 7 | north bend
# Processing Record 14 of Set 7 | dalhousie
# Processing Record 15 of Set 7 | tammisaari
# Processing Record 16 of Set 7 | marystown
# Processing Record 17 of Set 7 | haapiti
# Processing Record 18 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 19 of Set 7 | omboue
# Processing Record 20 of Set 7 | tiznit
# Processing Record 21 of Set 7 | skjervoy
# Processing Record 22 of Set 7 | eganville
# Processing Record 23 of Set 7 | egvekinot
# Processing Record 24 of Set 7 | emerald
# Processing Record 25 of Set 7 | avera
# Processing Record 26 of Set 7 | tarakan
# Processing Record 27 of Set 7 | ambon
# Processing Record 28 of Set 7 | nanortalik
# Processing Record 29 of Set 7 | sola
# Processing Record 30 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 7 | husavik
# Processing Record 32 of Set 7 | lompoc
# Processing Record 33 of Set 7 | cabo san lucas
# Processing Record 34 of Set 7 | wegorzewo
# Processing Record 35 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 7 | arica
# Processing Record 37 of Set 7 | kavieng
# Processing Record 38 of Set 7 | kaitangata
# Processing Record 39 of Set 7 | otradnoye
# Processing Record 40 of Set 7 | birao
# Processing Record 41 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 42 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 7 | bronnoysund
# Processing Record 44 of Set 7 | anadyr
# Processing Record 45 of Set 7 | kabelvag
# Processing Record 46 of Set 7 | rock springs
# Processing Record 47 of Set 7 | melo
# Processing Record 48 of Set 7 | shenzhen
# Processing Record 49 of Set 7 | kralendijk
# Processing Record 50 of Set 7 | nishihara
# Processing Record 1 of Set 8 | oytal
# Processing Record 2 of Set 8 | nome
# Processing Record 3 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 8 | bolonchen
# City not found. Skipping...
# Processing Record 5 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 6 of Set 8 | ishigaki
# Processing Record 7 of Set 8 | laredo
# Processing Record 8 of Set 8 | eureka
# Processing Record 9 of Set 8 | bengkulu
# Processing Record 10 of Set 8 | khani
# Processing Record 11 of Set 8 | bezhetsk
# Processing Record 12 of Set 8 | tucurui
# Processing Record 13 of Set 8 | castro verde
# Processing Record 14 of Set 8 | tarut
# Processing Record 15 of Set 8 | halden
# Processing Record 16 of Set 8 | odweyne
# Processing Record 17 of Set 8 | perth
# Processing Record 18 of Set 8 | otane
# Processing Record 19 of Set 8 | boa vista
# Processing Record 20 of Set 8 | puerto pinasco
# City not found. Skipping...
# Processing Record 21 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 8 | jiuquan
# Processing Record 23 of Set 8 | gresham
# Processing Record 24 of Set 8 | mehran
# Processing Record 25 of Set 8 | tateyama
# Processing Record 26 of Set 8 | uni
# Processing Record 27 of Set 8 | bessemer
# Processing Record 28 of Set 8 | tynda
# Processing Record 29 of Set 8 | ocos
# Processing Record 30 of Set 8 | sorland
# Processing Record 31 of Set 8 | tura
# Processing Record 32 of Set 8 | flinders
# Processing Record 33 of Set 8 | fairfield
# Processing Record 34 of Set 8 | sar-e pul
# Processing Record 35 of Set 8 | sioux lookout
# Processing Record 36 of Set 8 | trier
# Processing Record 37 of Set 8 | san policarpo
# Processing Record 38 of Set 8 | lethem
# Processing Record 39 of Set 8 | veraval
# Processing Record 40 of Set 8 | jiquilpan
# Processing Record 41 of Set 8 | natal
# Processing Record 42 of Set 8 | shimoda
# Processing Record 43 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 8 | namtsy
# Processing Record 45 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 8 | zhanaozen
# Processing Record 47 of Set 8 | labuhan
# Processing Record 48 of Set 8 | saint-joseph
# Processing Record 49 of Set 8 | paragominas
# Processing Record 50 of Set 8 | tual
# Processing Record 1 of Set 9 | taltal
# Processing Record 2 of Set 9 | baykit
# Processing Record 3 of Set 9 | neiafu
# Processing Record 4 of Set 9 | port macquarie
# Processing Record 5 of Set 9 | krynychky
# Processing Record 6 of Set 9 | pendleton
# Processing Record 7 of Set 9 | chabua
# Processing Record 8 of Set 9 | sao joao da barra
# Processing Record 9 of Set 9 | bastia
# Processing Record 10 of Set 9 | bolshoye murashkino
# Processing Record 11 of Set 9 | ngunguru
# Processing Record 12 of Set 9 | kelvington
# Processing Record 13 of Set 9 | tuatapere
# Processing Record 14 of Set 9 | saint-gabriel
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | meadow lake
# Processing Record 17 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 9 | abalak
# Processing Record 19 of Set 9 | karachi
# Processing Record 20 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 9 | tigil
# Processing Record 22 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 9 | saldanha
# Processing Record 24 of Set 9 | kahului
# Processing Record 25 of Set 9 | usinsk
# Processing Record 26 of Set 9 | serdobsk
# Processing Record 27 of Set 9 | kavaratti
# Processing Record 28 of Set 9 | amapa
# Processing Record 29 of Set 9 | soe
# Processing Record 30 of Set 9 | dzaoudzi
# Processing Record 31 of Set 9 | raudeberg
# Processing Record 32 of Set 9 | srednekolymsk
# Processing Record 33 of Set 9 | lebu
# Processing Record 34 of Set 9 | ketchikan
# Processing Record 35 of Set 9 | jinchang
# Processing Record 36 of Set 9 | torbay
# Processing Record 37 of Set 9 | abilene
# Processing Record 38 of Set 9 | kloulklubed
# Processing Record 39 of Set 9 | ilo
# Processing Record 40 of Set 9 | mabamba
# Processing Record 41 of Set 9 | kaiyuan
# Processing Record 42 of Set 9 | katghora
# Processing Record 43 of Set 9 | tabuk
# Processing Record 44 of Set 9 | roald
# Processing Record 45 of Set 9 | paamiut
# Processing Record 46 of Set 9 | parrita
# Processing Record 47 of Set 9 | karasjok
# Processing Record 48 of Set 9 | buraydah
# Processing Record 49 of Set 9 | san quintin
# Processing Record 50 of Set 9 | freeport
# Processing Record 1 of Set 10 | coroata
# Processing Record 2 of Set 10 | sheregesh
# Processing Record 3 of Set 10 | kolondieba
# Processing Record 4 of Set 10 | santa rosa
# Processing Record 5 of Set 10 | pansemal
# Processing Record 6 of Set 10 | alofi
# Processing Record 7 of Set 10 | coahuayana
# Processing Record 8 of Set 10 | balkanabat
# Processing Record 9 of Set 10 | san pedro
# Processing Record 10 of Set 10 | gat
# Processing Record 11 of Set 10 | fairbanks
# Processing Record 12 of Set 10 | brae
# Processing Record 13 of Set 10 | devils lake
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 16 of Set 10 | aripuana
# Processing Record 17 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 18 of Set 10 | fortuna
# Processing Record 19 of Set 10 | papagaios
# Processing Record 20 of Set 10 | iberia
# Processing Record 21 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 22 of Set 10 | moerai
# Processing Record 23 of Set 10 | dabhol
# Processing Record 24 of Set 10 | bosaso
# Processing Record 25 of Set 10 | severo-kurilsk
# Processing Record 26 of Set 10 | muscat
# Processing Record 27 of Set 10 | majene
# Processing Record 28 of Set 10 | humaita
# Processing Record 29 of Set 10 | maniitsoq
# Processing Record 30 of Set 10 | misratah
# Processing Record 31 of Set 10 | mushabani
# Processing Record 32 of Set 10 | nizhniy kuranakh
# Processing Record 33 of Set 10 | rudnyy
# Processing Record 34 of Set 10 | kikwit
# Processing Record 35 of Set 10 | vanimo
# Processing Record 36 of Set 10 | port lincoln
# Processing Record 37 of Set 10 | sri aman
# Processing Record 38 of Set 10 | ravar
# Processing Record 39 of Set 10 | san cristobal
# Processing Record 40 of Set 10 | smithers
# Processing Record 41 of Set 10 | sorong
# Processing Record 42 of Set 10 | visnes
# Processing Record 43 of Set 10 | cassilandia
# Processing Record 44 of Set 10 | alyangula
# Processing Record 45 of Set 10 | lisakovsk
# Processing Record 46 of Set 10 | alexandria
# Processing Record 47 of Set 10 | macenta
# Processing Record 48 of Set 10 | mogzon
# Processing Record 49 of Set 10 | buriti bravo
# Processing Record 50 of Set 10 | sulina
# Processing Record 1 of Set 11 | cuamba
# Processing Record 2 of Set 11 | etchoropo
# Processing Record 3 of Set 11 | constitucion
# Processing Record 4 of Set 11 | conceicao do araguaia
# Processing Record 5 of Set 11 | tawau
# Processing Record 6 of Set 11 | viransehir
# Processing Record 7 of Set 11 | ust-kuyga
# Processing Record 8 of Set 11 | haines junction
# Processing Record 9 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 11 | clyde river
# Processing Record 11 of Set 11 | port-gentil
# Processing Record 12 of Set 11 | la tuque
# Processing Record 13 of Set 11 | resistencia
# Processing Record 14 of Set 11 | hambantota
# Processing Record 15 of Set 11 | bubaque
# Processing Record 16 of Set 11 | inuvik
# Processing Record 17 of Set 11 | santa isabel do rio negro
# Processing Record 18 of Set 11 | sao felix do xingu
# Processing Record 19 of Set 11 | burnie
# Processing Record 20 of Set 11 | tilichiki
# Processing Record 21 of Set 11 | severnoye
# Processing Record 22 of Set 11 | dedougou
# Processing Record 23 of Set 11 | zhezkazgan
# Processing Record 24 of Set 11 | yulara
# Processing Record 25 of Set 11 | zuenoula
# Processing Record 26 of Set 11 | bandarbeyla
# Processing Record 27 of Set 11 | balikpapan
# Processing Record 28 of Set 11 | margate
# Processing Record 29 of Set 11 | rio grande
# Processing Record 30 of Set 11 | bilma
# Processing Record 31 of Set 11 | sao filipe
# Processing Record 32 of Set 11 | chiang klang
# Processing Record 33 of Set 11 | polson
# Processing Record 34 of Set 11 | hede
# Processing Record 35 of Set 11 | grindavik
# Processing Record 36 of Set 11 | tessalit
# Processing Record 37 of Set 11 | erenhot
# Processing Record 38 of Set 11 | trimbak
# Processing Record 39 of Set 11 | lebanon
# Processing Record 40 of Set 11 | christchurch
# Processing Record 41 of Set 11 | baculin
# Processing Record 42 of Set 11 | krasnoyarskiy
# Processing Record 43 of Set 11 | naryan-mar
# Processing Record 44 of Set 11 | benguela
# Processing Record 45 of Set 11 | jumla
# Processing Record 46 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 11 | bloomington
# Processing Record 48 of Set 11 | saint-pierre
# Processing Record 49 of Set 11 | mpika
# Processing Record 50 of Set 11 | mayo
# Processing Record 1 of Set 12 | buala
# Processing Record 2 of Set 12 | pemberton
# Processing Record 3 of Set 12 | pokhara
# Processing Record 4 of Set 12 | poso
# Processing Record 5 of Set 12 | kisangani
# Processing Record 6 of Set 12 | freetown
# Processing Record 7 of Set 12 | xichang
# Processing Record 8 of Set 12 | manado
# Processing Record 9 of Set 12 | puerto baquerizo moreno
# Processing Record 10 of Set 12 | kampot
# Processing Record 11 of Set 12 | tukums
# Processing Record 12 of Set 12 | inhambane
# Processing Record 13 of Set 12 | taybad
# Processing Record 14 of Set 12 | dicabisagan
# Processing Record 15 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 12 | conde
# Processing Record 17 of Set 12 | neon karlovasion
# Processing Record 18 of Set 12 | granada
# Processing Record 19 of Set 12 | mbekenyera
# Processing Record 20 of Set 12 | kayankulam
# Processing Record 21 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 22 of Set 12 | hobyo
# Processing Record 23 of Set 12 | atar
# Processing Record 24 of Set 12 | fort nelson
# Processing Record 25 of Set 12 | peleduy
# Processing Record 26 of Set 12 | callaguip
# Processing Record 27 of Set 12 | dalgopol
# Processing Record 28 of Set 12 | tsurugi
# Processing Record 29 of Set 12 | azuaga
# Processing Record 30 of Set 12 | shenjiamen
# Processing Record 31 of Set 12 | bejar
# Processing Record 32 of Set 12 | tambura
# Processing Record 33 of Set 12 | pallapatti
# Processing Record 34 of Set 12 | tripoli
# Processing Record 35 of Set 12 | ladson
# Processing Record 36 of Set 12 | babu
# Processing Record 37 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 12 | broome
# Processing Record 39 of Set 12 | manaus
# Processing Record 40 of Set 12 | rotifunk
# Processing Record 41 of Set 12 | seoul
# Processing Record 42 of Set 12 | fiche
# Processing Record 43 of Set 12 | bulgan
# Processing Record 44 of Set 12 | huangchuan
# Processing Record 45 of Set 12 | elban
# Processing Record 46 of Set 12 | tocache
# Processing Record 47 of Set 12 | nhulunbuy
# Processing Record 48 of Set 12 | yumaguzino
# Processing Record 49 of Set 12 | tabou
# Processing Record 50 of Set 12 | shitkino
# Processing Record 1 of Set 13 | doba
# Processing Record 2 of Set 13 | krasnaya gorbatka
# Processing Record 3 of Set 13 | kars
# Processing Record 4 of Set 13 | whitehorse
# Processing Record 5 of Set 13 | takoradi
# Processing Record 6 of Set 13 | vestmannaeyjar
# Processing Record 7 of Set 13 | surt
# Processing Record 8 of Set 13 | batsfjord
# Processing Record 9 of Set 13 | namibe
# Processing Record 10 of Set 13 | poum
# Processing Record 11 of Set 13 | antalaha
# Processing Record 12 of Set 13 | bac lieu
# Processing Record 13 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 13 | belaya gora
# Processing Record 15 of Set 13 | latung
# Processing Record 16 of Set 13 | tymovskoye
# Processing Record 17 of Set 13 | borogontsy
# Processing Record 18 of Set 13 | thaba-tseka
# Processing Record 19 of Set 13 | te anau
# Processing Record 20 of Set 13 | kuryk
# Processing Record 21 of Set 13 | vilyuysk
# Processing Record 22 of Set 13 | bonthe
# Processing Record 23 of Set 13 | valleyview
# Processing Record 24 of Set 13 | cartagena
# Processing Record 25 of Set 13 | ayacucho
# Processing Record 26 of Set 13 | katangli
# Processing Record 27 of Set 13 | port hedland
# Processing Record 28 of Set 13 | lakhdenpokhya
# Processing Record 29 of Set 13 | solnechnyy
# Processing Record 30 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 13 | vernon
# Processing Record 32 of Set 13 | sept-iles
# Processing Record 33 of Set 13 | walvis bay
# Processing Record 34 of Set 13 | mangrol
# Processing Record 35 of Set 13 | port augusta
# Processing Record 36 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 37 of Set 13 | san ramon
# Processing Record 38 of Set 13 | khuzhir
# Processing Record 39 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 13 | sechura
# Processing Record 41 of Set 13 | vao
# Processing Record 42 of Set 13 | mehriz
# Processing Record 43 of Set 13 | nerchinskiy zavod
# Processing Record 44 of Set 13 | akdepe
# Processing Record 45 of Set 13 | wageningen
# Processing Record 46 of Set 13 | saint paul
# Processing Record 47 of Set 13 | port hardy
# Processing Record 48 of Set 13 | glen allen
# Processing Record 49 of Set 13 | muisne
# Processing Record 50 of Set 13 | mazagao
# Processing Record 1 of Set 14 | oranjemund
# Processing Record 2 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 3 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 14 | orgun
# City not found. Skipping...
# Processing Record 5 of Set 14 | coihaique
# Processing Record 6 of Set 14 | marovoay
# Processing Record 7 of Set 14 | redlands
# Processing Record 8 of Set 14 | merrill
# Processing Record 9 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 14 | villazon
# Processing Record 11 of Set 14 | lavrentiya
# Processing Record 12 of Set 14 | la paz
# Processing Record 13 of Set 14 | carroll
# Processing Record 14 of Set 14 | grand gaube
# Processing Record 15 of Set 14 | gandiaye
# Processing Record 16 of Set 14 | strelka
# Processing Record 17 of Set 14 | lucapa
# Processing Record 18 of Set 14 | zhigansk
# Processing Record 19 of Set 14 | pasighat
# Processing Record 20 of Set 14 | wajir
# Processing Record 21 of Set 14 | rangia
# Processing Record 22 of Set 14 | boddam
# Processing Record 23 of Set 14 | ergani
# Processing Record 24 of Set 14 | kawalu
# Processing Record 25 of Set 14 | liverpool
# Processing Record 26 of Set 14 | opuwo
# Processing Record 27 of Set 14 | rapar
# Processing Record 28 of Set 14 | pisco
# Processing Record 29 of Set 14 | ilebo
# Processing Record 30 of Set 14 | tubuala
# Processing Record 31 of Set 14 | presidencia roque saenz pena
# Processing Record 32 of Set 14 | kieta
# Processing Record 33 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 34 of Set 14 | berezhany
# Processing Record 35 of Set 14 | longavi
# Processing Record 36 of Set 14 | esik
# Processing Record 37 of Set 14 | kaberamaido
# Processing Record 38 of Set 14 | verkhnevilyuysk
# Processing Record 39 of Set 14 | ha
# City not found. Skipping...
# Processing Record 40 of Set 14 | saint anthony
# Processing Record 41 of Set 14 | ukiah
# Processing Record 42 of Set 14 | zyryanovsk
# Processing Record 43 of Set 14 | alice springs
# Processing Record 44 of Set 14 | bone
# Processing Record 45 of Set 14 | springbok
# Processing Record 46 of Set 14 | ismailia
# Processing Record 47 of Set 14 | iralaya
# Processing Record 48 of Set 14 | coos bay
# Processing Record 49 of Set 14 | poya
# Processing Record 50 of Set 14 | trairi
# Processing Record 1 of Set 15 | elizabeth city
# Processing Record 2 of Set 15 | san ignacio
# Processing Record 3 of Set 15 | kununurra
# Processing Record 4 of Set 15 | west bay
# Processing Record 5 of Set 15 | shar
# Processing Record 6 of Set 15 | zyryanovskiy
# City not found. Skipping...
# Processing Record 7 of Set 15 | yining
# Processing Record 8 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 9 of Set 15 | indiaroba
# Processing Record 10 of Set 15 | bocicoiu mare
# Processing Record 11 of Set 15 | kakonko
# Processing Record 12 of Set 15 | necochea
# Processing Record 13 of Set 15 | tongren
# Processing Record 14 of Set 15 | lakatoro
# Processing Record 15 of Set 15 | molodizhne
# Processing Record 16 of Set 15 | burhar
# Processing Record 17 of Set 15 | san martin
# Processing Record 18 of Set 15 | kaka
# Processing Record 19 of Set 15 | sabha
# Processing Record 20 of Set 15 | palmerston
# Processing Record 21 of Set 15 | taitung
# Processing Record 22 of Set 15 | mapiripan
# Processing Record 23 of Set 15 | bergen
# Processing Record 24 of Set 15 | quesnel
# Processing Record 25 of Set 15 | gualaquiza
# Processing Record 26 of Set 15 | jackson
# Processing Record 27 of Set 15 | daru
# Processing Record 28 of Set 15 | zhob
# Processing Record 29 of Set 15 | sovetskaya gavan
# Processing Record 30 of Set 15 | kabala
# Processing Record 31 of Set 15 | teknaf
# Processing Record 32 of Set 15 | elkhart
# Processing Record 33 of Set 15 | turukhansk
# Processing Record 34 of Set 15 | malanville
# Processing Record 35 of Set 15 | dunedin
# Processing Record 36 of Set 15 | yabelo
# Processing Record 37 of Set 15 | morondava
# Processing Record 38 of Set 15 | lichuan
# Processing Record 39 of Set 15 | tautira
# Processing Record 40 of Set 15 | la ronge
# Processing Record 41 of Set 15 | mareeba
# Processing Record 42 of Set 15 | martil
# Processing Record 43 of Set 15 | naze
# Processing Record 44 of Set 15 | hirara
# Processing Record 45 of Set 15 | flin flon
# Processing Record 46 of Set 15 | nybro
# Processing Record 47 of Set 15 | altay
# Processing Record 48 of Set 15 | victor harbor
# Processing Record 49 of Set 15 | elva
# Processing Record 50 of Set 15 | bonavista
# Processing Record 1 of Set 16 | ciocile
# Processing Record 2 of Set 16 | chimbote
# Processing Record 3 of Set 16 | providencia
# Processing Record 4 of Set 16 | qixingtai
# Processing Record 5 of Set 16 | sobolevo
# Processing Record 6 of Set 16 | monrovia
# Processing Record 7 of Set 16 | manitouwadge
# Processing Record 8 of Set 16 | san joaquin
# Processing Record 9 of Set 16 | okha
# Processing Record 10 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 16 | hofn
# Processing Record 12 of Set 16 | northam
# Processing Record 13 of Set 16 | lubango
# Processing Record 14 of Set 16 | quatre cocos
# Processing Record 15 of Set 16 | marawi
# Processing Record 16 of Set 16 | atambua
# Processing Record 17 of Set 16 | xining
# Processing Record 18 of Set 16 | ibra
# Processing Record 19 of Set 16 | sulangan
# Processing Record 20 of Set 16 | mwinilunga
# Processing Record 21 of Set 16 | cervignano del friuli
# Processing Record 22 of Set 16 | mildura
# Processing Record 23 of Set 16 | loubomo
# Processing Record 24 of Set 16 | cao bang
# Processing Record 25 of Set 16 | oranjestad
# Processing Record 26 of Set 16 | la palma
# Processing Record 27 of Set 16 | gamba
# Processing Record 28 of Set 16 | codrington
# Processing Record 29 of Set 16 | beloha
# Processing Record 30 of Set 16 | saint-jean-de-braye
# Processing Record 31 of Set 16 | tutin
# Processing Record 32 of Set 16 | kutum
# Processing Record 33 of Set 16 | praya
# Processing Record 34 of Set 16 | saqqez
# Processing Record 35 of Set 16 | taoudenni
# Processing Record 36 of Set 16 | imbituba
# Processing Record 37 of Set 16 | outjo
# Processing Record 38 of Set 16 | praia da vitoria
# Processing Record 39 of Set 16 | notse
# Processing Record 40 of Set 16 | kanungu
# Processing Record 41 of Set 16 | neftcala
# Processing Record 42 of Set 16 | polunochnoye
# Processing Record 43 of Set 16 | varva
# Processing Record 44 of Set 16 | abong mbang
# Processing Record 45 of Set 16 | launceston
# Processing Record 46 of Set 16 | kushmurun
# Processing Record 47 of Set 16 | chebarkul
# Processing Record 48 of Set 16 | upata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# %%
# Reorder columns 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Vallenar      CL -28.5708  -70.7581     86.22        24           1
# 1       Luwuk      ID  -0.9516  122.7875     77.79        87         100
# 2        Mana      GF   5.6592  -53.7767     80.87        73          95
# 3    Souillac      MU -20.5167   57.5167     79.18        83          40
# 4        Sapa      PH   5.1544  120.3241     79.25        82          98
# 5    Olafsvik      IS  64.8945  -23.7142     34.12        68         100
# 6    San Juan      AR -31.5375  -68.5364     85.39        15          43
# 7      Barrow      US  71.2906 -156.7887     -2.18        71           0
# 8  Nikolskoye      RU  59.7035   30.7861     26.80        84          91
# 9       Vaini      TO -21.2000 -175.2000     77.16        94          40
#
#    Wind Speed          Current Description
# 0        9.46                    clear sky
# 1        1.83                moderate rain
# 2       11.21              overcast clouds
# 3        0.00             scattered clouds
# 4        8.55              overcast clouds
# 5       21.39              overcast clouds
# 6        7.63             scattered clouds
# 7       20.71                         haze
# 8        4.36              overcast clouds
# 9        6.91  light intensity shower rain

# %%
#Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
